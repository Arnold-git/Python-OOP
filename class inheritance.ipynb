# %%
class Employee:
    
    raise_amount = 1.04
    num_of_emps = 0
    def __init__(self, first, last, pay): #self ==> is the instance of the class Employee
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + "." + last + "@company.com"
        Employee.num_of_emps += 1
        
    def fullname(self): # a method within a class
        return "{} {}".format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)
        
class Developer(Employee):
    pass

dev_1 = Developer("Arnold", "Ighiwiyisi", 50000)

dev_2 = Developer("Efosa", "Osagie", 60000)
print(help(Developer))
# print(dev_1.email)
# print(dev_1.email)
# Out:
# Help on class Developer in module __main__:
#
# class Developer(Employee)
#  |  Developer(first, last, pay)
#  |
#  |  Method resolution order:
#  |      Developer
#  |      Employee
#  |      builtins.object
#  |
#  |  Methods inherited from Employee:
#  |
#  |  __init__(self, first, last, pay)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  apply_raise(self)
#  |
#  |  fullname(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Employee:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from Employee:
#  |
#  |  num_of_emps = 2
#  |
#  |  raise_amount = 1.04
#
# None

# %%
class Employee:
    
    raise_amount = 1.04
    num_of_emps = 0
    def __init__(self, first, last, pay): #self ==> is the instance of the class Employee
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + "." + last + "@company.com"
        Employee.num_of_emps += 1
        
    def fullname(self): # a method within a class
        return "{} {}".format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)
        
class Developer(Employee):
    pass
#     raise_amount = 1.10

dev_1 = Developer("Arnold", "Ighiwiyisi", 50000)

dev_2 = Developer("Efosa", "Osagie", 60000)

# print(dev_1.email)
# print(dev_1.email)

print(dev_1.pay)
dev_1.apply_raise()
print(dev_1.pay)
# Out:
# 50000
# 55000

# %%
class Employee:
    
    raise_amount = 1.04
    num_of_emps = 0 #class object attribute
    def __init__(self, first, last, pay): #self ==> is the instance of the class Employee
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + "." + last + "@company.com"
        Employee.num_of_emps += 1
        
    def fullname(self): # a method within a class
        return "{} {}".format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)
        
class Developer(Employee):
    raise_amount = 1.10
    def __init__(self, first, last, pay, prog_lang, location):
        super().__init__(first, last, pay)
        self.prog_lang = prog_lang
        self.location = location
#     raise_amount = 1.10

dev_1 = Developer("Arnold", "Ighiwiyisi", 50000, "Python", "Edo")

dev_2 = Developer("Efosa", "Osagie", 60000, "Java", "Lagos")

# print(dev_1.email)
# print(dev_1.email)
print(help(Developer))
print(dev_1.email)
print(dev_1.prog_lang)
print(dev_1.location)
# Out:
# Help on class Developer in module __main__:
#
# class Developer(Employee)
#  |  Developer(first, last, pay, prog_lang, location)
#  |
#  |  Method resolution order:
#  |      Developer
#  |      Employee
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, first, last, pay, prog_lang, location)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  raise_amount = 1.1
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Employee:
#  |
#  |  apply_raise(self)
#  |
#  |  fullname(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Employee:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
# ...

# %%
class Employee:
    
    raise_amount = 1.04
    num_of_emps = 0
    def __init__(self, first, last, pay): #self ==> is the instance of the class Employee
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + "." + last + "@company.com"
        Employee.num_of_emps += 1
        
    def fullname(self): # a method within a class
        return "{} {}".format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)
        
class Developer(Employee):
    raise_amount = 1.10
    def __init__(self, first, last, pay, prog_lang):
        super().__init__(first, last, pay)
        self.prog_lang = prog_lang

class Manager(Employee):
    def __init__(self, first, last, pay, employees=None):
        super().__init__(first, last, pay)
        if employees is None:
            self.employee = []
        else:
            self.employees = employees
        
    def add_emp(self, emp):
        if emp not in self.employees:
            self.employees.append(emp)
    def remove_emp(self, emp):
        if emp in self.employees:
            self.employees.remove(emp)
    def print_emp(self):
        for emp in self.employees:
            print('-->', emp.fullname())
    
        

dev_1 = Developer("Arnold", "Ighiwiyisi", 50000, "Python")

dev_2 = Developer("Efosa", "Osagie", 60000, "Java")

mgr_1 = Manager('Sue', "Smith", 9000, [dev_1])
print(mgr_1.email)
mgr_1.add_emp(dev_2)
mgr_1.remove_emp(dev_1)
mgr_1.print_emp()
# Out:
# Sue.Smith@company.com
# --> Efosa Osagie

# %%
class Employee:
    
    raise_amount = 1.04
    num_of_emps = 0
    def __init__(self, first, last, pay): #self ==> is the instance of the class Employee
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + "." + last + "@company.com"
        Employee.num_of_emps += 1
        
    def fullname(self): # a method within a class
        return "{} {}".format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)
        
class Developer(Employee):
    raise_amount = 1.10
    def __init__(self, first, last, pay, prog_lang):
        super().__init__(first, last, pay)
        self.prog_lang = prog_lang

class Manager(Employee):
    def __init__(self, first, last, pay, employees=None):
        super().__init__(first, last, pay)
        if employees is None:
            self.employee = []
        else:
            self.employees = employees
        
    def add_emp(self, emp):
        if emp not in self.employees:
            self.employees.append(emp)
    def remove_emp(self, emp):
        if emp in self.employees:
            self.employees.remove(emp)
    def print_emp(self):
        for emp in self.employees:
            print('-->', emp.fullname())
    
        

dev_1 = Developer("Arnold", "Ighiwiyisi", 50000, "Python")

dev_2 = Developer("Efosa", "Osagie", 60000, "Java")

mgr_1 = Manager('Sue', "smith", 9000, [dev_1])
# isinstance(mgr_1, Manager)
# isinstance(mgr_1, Employee)
# isinstance(mgr_1,Developer)
# issubclass(Developer, Employee)
# issubclass(Developer, Manager)
# Out:
# False
